# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_mode = "large"
df = pd.read_csv(f"result/{data_mode}.csv",index_col=0)
seed = 1
# Calculate the UGF (Utility Gap Fairness)
metric_components = ["test_Y_MRR_male", "test_Y_HR_5_male", "test_Y_HR_10_male",
                    "test_Y_NDCG_5_male", "test_Y_NDCG_10_male"]
df_new = df[metric_components].subtract(
    df[["test_Y_MRR_female", "test_Y_HR_5_female", "test_Y_HR_10_female",
        "test_Y_NDCG_5_female", "test_Y_NDCG_10_female"]].values
)
df[["test_Y_MRR_UGF", "test_Y_HR_5_UGF", "test_Y_HR_10_UGF",
    "test_Y_NDCG_5_UGF", "test_Y_NDCG_10_UGF"]] = df_new
df = df[df['seed']==seed]
df[["scenario","training_setting","test_Y_NDCG_10","test_Y_NDCG_10_male","test_Y_NDCG_10_female","test_Y_NDCG_10_UGF"]]
# Out:
#           scenario training_setting  test_Y_NDCG_10  test_Y_NDCG_10_male  \
# 0  thriller_comedy              our        0.159898             0.165648
# 0  thriller_comedy           single        0.128760             0.135201
# 0  thriller_comedy            C2DSR        0.153419             0.158384
# 0     action_drama              our        0.146572             0.150646
# 0     action_drama           single        0.130759             0.128304
# 0     action_drama            C2DSR        0.144681             0.144024
# 0    action_comedy              our        0.140522             0.147525
# 0    action_comedy           single        0.125415             0.130836
# 0    action_comedy            C2DSR        0.146875             0.152541
# 0    sci-fi_comedy              our        0.171123             0.181642
# 0    sci-fi_comedy           single        0.155348             0.158862
# 0    sci-fi_comedy            C2DSR        0.166499             0.174409
# 0     sci-fi_drama              our        0.181547             0.190318
# 0     sci-fi_drama           single        0.166160             0.172986
# 0     sci-fi_drama            C2DSR        0.179207             0.184624
#
#    test_Y_NDCG_10_female  test_Y_NDCG_10_UGF
# 0               0.142383            0.023265
# 0               0.109145            0.026056
# 0               0.138295            0.020089
# 0               0.131901            0.018745
# 0               0.139599           -0.011295
# 0               0.147047           -0.003023
# 0               0.115754            0.031771
# 0               0.106242            0.024594
# 0               0.126834            0.025708
# 0               0.131064            0.050579
# 0               0.141963            0.016899
# 0               0.136379            0.038029
# 0               0.147088            0.043230
# 0               0.139342            0.033644
# 0               0.157922            0.026702

# %%
data_mode = "mid"
df = pd.read_csv(f"result/{data_mode}.csv",index_col=0)
seed = 0
# Calculate the UGF (Utility Gap Fairness)
metric_components = ["test_Y_MRR_male", "test_Y_HR_5_male", "test_Y_HR_10_male",
                    "test_Y_NDCG_5_male", "test_Y_NDCG_10_male"]
df_new = df[metric_components].subtract(
    df[["test_Y_MRR_female", "test_Y_HR_5_female", "test_Y_HR_10_female",
        "test_Y_NDCG_5_female", "test_Y_NDCG_10_female"]].values
)
df[["test_Y_MRR_UGF", "test_Y_HR_5_UGF", "test_Y_HR_10_UGF",
    "test_Y_NDCG_5_UGF", "test_Y_NDCG_10_UGF"]] = df_new
df = df[df['seed']==seed]
df[["scenario","training_setting","test_Y_NDCG_10","test_Y_NDCG_10_male","test_Y_NDCG_10_female","test_Y_NDCG_10_UGF"]]
# Out:
#            scenario training_setting  test_Y_NDCG_10  test_Y_NDCG_10_male  \
# 0    thriller_drama              our        0.173118             0.177842
# 0    thriller_drama           single        0.148269             0.154970
# 0    thriller_drama            C2DSR        0.165813             0.174097
# 0   adventure_drama              our        0.176783             0.189293
# 0   adventure_drama           single        0.171801             0.180004
# 0   adventure_drama            C2DSR        0.174119             0.183568
# 0  adventure_comedy              our        0.151906             0.161068
# 0  adventure_comedy           single        0.133728             0.140479
# 0  adventure_comedy            C2DSR        0.159235             0.162277
#
#    test_Y_NDCG_10_female  test_Y_NDCG_10_UGF
# 0               0.156058            0.021784
# 0               0.124067            0.030903
# 0               0.135898            0.038199
# 0               0.134496            0.054797
# 0               0.144073            0.035931
# 0               0.142178            0.041390
# 0               0.115576            0.045492
# 0               0.106960            0.033519
# 0               0.147171            0.015106

# %%
data_mode = "small"
df = pd.read_csv(f"result/{data_mode}.csv",index_col=0)
seed = 0
# Calculate the UGF (Utility Gap Fairness)
metric_components = ["test_Y_MRR_male", "test_Y_HR_5_male", "test_Y_HR_10_male",
                    "test_Y_NDCG_5_male", "test_Y_NDCG_10_male"]
df_new = df[metric_components].subtract(
    df[["test_Y_MRR_female", "test_Y_HR_5_female", "test_Y_HR_10_female",
        "test_Y_NDCG_5_female", "test_Y_NDCG_10_female"]].values
)
df[["test_Y_MRR_UGF", "test_Y_HR_5_UGF", "test_Y_HR_10_UGF",
    "test_Y_NDCG_5_UGF", "test_Y_NDCG_10_UGF"]] = df_new
df = df[df['seed']==seed]
df[["scenario","training_setting","test_Y_NDCG_10","test_Y_NDCG_10_male","test_Y_NDCG_10_female","test_Y_NDCG_10_UGF"]]
# Out:
#              scenario training_setting  test_Y_NDCG_10  test_Y_NDCG_10_male  \
# 0    animation_comedy              our        0.117184             0.093620
# 0    animation_comedy           single        0.100712             0.094749
# 0    animation_comedy            C2DSR        0.120758             0.101136
# 0      mystery_comedy              our        0.115278             0.117676
# 0      mystery_comedy           single        0.113339             0.117643
# 0      mystery_comedy            C2DSR        0.125141             0.137623
# 0    children's_drama              our        0.108617             0.114256
# 0    children's_drama           single        0.113761             0.121611
# 0    children's_drama            C2DSR        0.129989             0.143421
# 0  documentary_comedy              our        0.084958             0.081844
# 0  documentary_comedy           single        0.039889             0.058171
# 0  documentary_comedy            C2DSR        0.057345             0.036952
# 0     animation_drama              our        0.136026             0.137271
# 0     animation_drama           single        0.130907             0.150535
# 0     animation_drama            C2DSR        0.140001             0.155306
# 0   children's_comedy              our        0.114908             0.105701
# 0   children's_comedy           single        0.109896             0.102851
# 0   children's_comedy            C2DSR        0.099843             0.090517
# 0   documentary_drama              our        0.058116             0.054531
# 0   documentary_drama           single        0.044372             0.056318
# 0   documentary_drama            C2DSR        0.033946             0.026521
#
#    test_Y_NDCG_10_female  test_Y_NDCG_10_UGF
# 0               0.172781           -0.079161
# 0               0.114782           -0.020033
# 0               0.167055           -0.065919
# 0               0.107260            0.010417
# 0               0.098950            0.018693
# 0               0.083415            0.054207
# 0               0.094955            0.019301
# 0               0.094738            0.026873
# 0               0.097442            0.045979
# 0               0.091750           -0.009906
# 0               0.000000            0.058171
# 0               0.101838           -0.064886
# 0               0.132625            0.004646
# 0               0.077257            0.073279
# 0               0.098168            0.057138
# 0               0.138994           -0.033293
# 0               0.128325           -0.025474
# 0               0.124241           -0.033724
# 0               0.071429           -0.016897
# 0               0.000000            0.056318
# 0               0.061525           -0.035004
