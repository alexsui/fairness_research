# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_mode = "large"
df = pd.read_csv(f"result/{data_mode}.csv",index_col=0)
seed = 2
# Calculate the UGF (Utility Gap Fairness)
metric_components = ["test_Y_MRR_male", "test_Y_HR_5_male", "test_Y_HR_10_male",
                    "test_Y_NDCG_5_male", "test_Y_NDCG_10_male"]
df_new = df[metric_components].subtract(
    df[["test_Y_MRR_female", "test_Y_HR_5_female", "test_Y_HR_10_female",
        "test_Y_NDCG_5_female", "test_Y_NDCG_10_female"]].values
)
df[["test_Y_MRR_UGF", "test_Y_HR_5_UGF", "test_Y_HR_10_UGF",
    "test_Y_NDCG_5_UGF", "test_Y_NDCG_10_UGF"]] = df_new
df = df[df['seed']==seed]
# df.groupby(["seed","scenario","training_setting","alpha","substitute_ratio"]).mean()
df[df['scenario'] == "sci-fi_drama"][["scenario","training_setting","alpha","substitute_ratio","test_Y_NDCG_10","test_Y_NDCG_10_male","test_Y_NDCG_10_female","test_Y_NDCG_10_UGF"]]
# Out:
#        scenario training_setting  alpha  substitute_ratio  test_Y_NDCG_10  \
# 0  sci-fi_drama              our    0.5               0.7        0.182935
# 0  sci-fi_drama              our    0.5               0.8        0.190095
# 0  sci-fi_drama              our    0.5               0.9        0.183525
# 0  sci-fi_drama              our    0.6               0.7        0.182127
# 0  sci-fi_drama              our    0.6               0.8        0.181498
# 0  sci-fi_drama              our    0.6               0.9        0.178997
# 0  sci-fi_drama              our    0.7               0.7        0.187971
# 0  sci-fi_drama              our    0.7               0.8        0.186100
# 0  sci-fi_drama              our    0.7               0.9        0.185286
# 0  sci-fi_drama           single    0.5               0.7        0.165817
# 0  sci-fi_drama           single    0.5               0.8        0.165817
# 0  sci-fi_drama           single    0.5               0.9        0.165817
# 0  sci-fi_drama           single    0.6               0.7        0.165817
# 0  sci-fi_drama           single    0.6               0.8        0.165817
# 0  sci-fi_drama           single    0.6               0.9        0.165817
# 0  sci-fi_drama           single    0.7               0.7        0.165817
# 0  sci-fi_drama           single    0.7               0.8        0.165817
# 0  sci-fi_drama           single    0.7               0.9        0.165817
# 0  sci-fi_drama            C2DSR    0.5               0.7        0.183454
# 0  sci-fi_drama            C2DSR    0.5               0.8        0.183454
# 0  sci-fi_drama            C2DSR    0.5               0.9        0.183454
# 0  sci-fi_drama            C2DSR    0.6               0.7        0.183454
# 0  sci-fi_drama            C2DSR    0.6               0.8        0.183454
# 0  sci-fi_drama            C2DSR    0.6               0.9        0.183454
# 0  sci-fi_drama            C2DSR    0.7               0.7        0.183454
# 0  sci-fi_drama            C2DSR    0.7               0.8        0.183454
# 0  sci-fi_drama            C2DSR    0.7               0.9        0.183454
#
#    test_Y_NDCG_10_male  test_Y_NDCG_10_female  test_Y_NDCG_10_UGF
# 0             0.193727               0.140537            0.053190
# 0             0.198837               0.155747            0.043091
# 0             0.193360               0.144884            0.048475
# 0             0.188137               0.158515            0.029622
# 0             0.188401               0.154377            0.034025
# 0             0.185432               0.153713            0.031719
# 0             0.192530               0.170063            0.022466
# 0             0.191868               0.163436            0.028432
# 0             0.190537               0.164656            0.025881
# 0             0.180723               0.107253            0.073469
# 0             0.180723               0.107253            0.073469
# 0             0.180723               0.107253            0.073469
# 0             0.180723               0.107253            0.073469
# 0             0.180723               0.107253            0.073469
# 0             0.180723               0.107253            0.073469
# 0             0.180723               0.107253            0.073469
# 0             0.180723               0.107253            0.073469
# 0             0.180723               0.107253            0.073469
# 0             0.190707               0.154959            0.035748
# 0             0.190707               0.154959            0.035748
# 0             0.190707               0.154959            0.035748
# 0             0.190707               0.154959            0.035748
# 0             0.190707               0.154959            0.035748
# 0             0.190707               0.154959            0.035748
# 0             0.190707               0.154959            0.035748
# 0             0.190707               0.154959            0.035748
# 0             0.190707               0.154959            0.035748

# %%
data_mode = "mid"
df = pd.read_csv(f"result/{data_mode}.csv",index_col=0)
seed = 0
# Calculate the UGF (Utility Gap Fairness)
metric_components = ["test_Y_MRR_male", "test_Y_HR_5_male", "test_Y_HR_10_male",
                    "test_Y_NDCG_5_male", "test_Y_NDCG_10_male"]
df_new = df[metric_components].subtract(
    df[["test_Y_MRR_female", "test_Y_HR_5_female", "test_Y_HR_10_female",
        "test_Y_NDCG_5_female", "test_Y_NDCG_10_female"]].values
)
df[["test_Y_MRR_UGF", "test_Y_HR_5_UGF", "test_Y_HR_10_UGF",
    "test_Y_NDCG_5_UGF", "test_Y_NDCG_10_UGF"]] = df_new
df = df[df['seed']==seed]
df[["scenario","training_setting","test_Y_NDCG_10","test_Y_NDCG_10_male","test_Y_NDCG_10_female","test_Y_NDCG_10_UGF"]]
# Out:
#            scenario training_setting  test_Y_NDCG_10  test_Y_NDCG_10_male  \
# 0    thriller_drama              our        0.173118             0.177842
# 0    thriller_drama           single        0.148269             0.154970
# 0    thriller_drama            C2DSR        0.165813             0.174097
# 0   adventure_drama              our        0.176783             0.189293
# 0   adventure_drama           single        0.171801             0.180004
# 0   adventure_drama            C2DSR        0.174119             0.183568
# 0  adventure_comedy              our        0.151906             0.161068
# 0  adventure_comedy           single        0.133728             0.140479
# 0  adventure_comedy            C2DSR        0.159235             0.162277
#
#    test_Y_NDCG_10_female  test_Y_NDCG_10_UGF
# 0               0.156058            0.021784
# 0               0.124067            0.030903
# 0               0.135898            0.038199
# 0               0.134496            0.054797
# 0               0.144073            0.035931
# 0               0.142178            0.041390
# 0               0.115576            0.045492
# 0               0.106960            0.033519
# 0               0.147171            0.015106

# %%
data_mode = "small"
df = pd.read_csv(f"result/{data_mode}.csv",index_col=0)
seed = 0
# Calculate the UGF (Utility Gap Fairness)
metric_components = ["test_Y_MRR_male", "test_Y_HR_5_male", "test_Y_HR_10_male",
                    "test_Y_NDCG_5_male", "test_Y_NDCG_10_male"]
df_new = df[metric_components].subtract(
    df[["test_Y_MRR_female", "test_Y_HR_5_female", "test_Y_HR_10_female",
        "test_Y_NDCG_5_female", "test_Y_NDCG_10_female"]].values
)
df[["test_Y_MRR_UGF", "test_Y_HR_5_UGF", "test_Y_HR_10_UGF",
    "test_Y_NDCG_5_UGF", "test_Y_NDCG_10_UGF"]] = df_new
df = df[(df['scenario']=='animation_drama')]
df[["scenario","training_setting","test_Y_NDCG_10","test_Y_NDCG_10_male","test_Y_NDCG_10_female","test_Y_NDCG_10_UGF"]]
# Out:
#           scenario training_setting  test_Y_NDCG_10  test_Y_NDCG_10_male  \
# 0  animation_drama           single        0.047746             0.050817
# 0  animation_drama            C2DSR        0.044230             0.052630
# 0  animation_drama              our        0.052391             0.056113
#
#    test_Y_NDCG_10_female  test_Y_NDCG_10_UGF
# 0               0.039349            0.011468
# 0               0.021269            0.031360
# 0               0.042219            0.013894
